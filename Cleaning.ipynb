# %%
import pandas as pd
import re

# %%
path = 'EEO_artilces.csv'
pd.read_csv(path)
# Out:
#                                                  Title  \
# 0    Still a private universe? Community college st...
# 1    Reconsidering the goals of evolution education...
# 2    Scientists benefit greatly from K-12 partnersh...
# 3    Popular media and the bombardment of evolution...
# 4    Scientists’ and teachers’ attitudes toward rel...
# ..                                                 ...
# 661  Gordy Slack, The Battle Over the Meaning of Ev...
# 662                   What’s So Special About Science?
# 663                            The Question of Purpose
# 664  Views from Understanding Evolution: Parasites ...
# 665                Evolution as Fact, Theory, and Path
#
#                                                Authors  \
# 0    ['Meredith A. Dorner', 'Philip Sadler', 'Brian...
# 1                               ['Kostas Kampourakis']
# 2    ['Bruce J. MacFadden', 'Claudia Vargas Vergara...
# 3    ['Daniel G. Ferguson', 'Jessica Abele', 'Sarah...
# ...
